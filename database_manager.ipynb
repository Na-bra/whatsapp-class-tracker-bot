# %% [markdown]
# # Database manager notebook
#
# This notebook intentionally contains no executable code cells. Use it as
# a placeholder / documentation space for `classes.json` management.
# Add code cells locally when you are ready to implement data utilities.
